# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread("/content/sp.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=730x1095>

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-72299047> in <cell line: 0>()
#       2 get_ipython().system('pip install cv2')
#       3 img = cv.imread("/1 computer.jpg")
# ----> 4 cv.waitForKey(4)
#       5 cv.imshow("image",img)
#
# AttributeError: module 'cv2' has no attribute 'waitForKey'
