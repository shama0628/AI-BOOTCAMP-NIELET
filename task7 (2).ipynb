# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

x= np.array([1,2,3,4,5]).reshape((-1,1))
y=np.array([1,2,3,4,5])
model= LinearRegression()
model.fit(x,y)
print("slope",model.coef_[0])
print("intercept",model.intercept_)
x_new = np.array([6]).reshape((-1,1))
y_pred =model.predict(x_new)
print("predicted value y for x=6",y_pred[0])
plt.scatter(x,y,color='red',label="data point")
plt.plot(x,model.predict(x),color='blue',label="Regression line")
plt.scatter(x_new,y_pred,color='blue',label="Regression line")
plt.xlabel('x')
plt.ylabel('y')
plt.title("simple linear regression")
plt.legend()
plt.show()
# Out:
# slope 1.0
# intercept 0.0
# predicted value y for x=6 6.0
