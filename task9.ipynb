# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.8, random_state=82)
kmeans = KMeans(n_clusters=4,random_state=42,n_init="auto")
kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
plt.figure(figsize=(8,6))
plt.scatter(X[:,0],X[:,1],c=labels,cmap='viridis')
plt.scatter(centroids[:,0],centroids[:,1],c="brown",marker="x",s=200,label="centroids")
plt.title("k-means clustering")
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.legend()
plt.grid(True)
plt.show()
print("Cluster centroid:\n",centroids)
# Out:
# Cluster centroid:
#  [[-0.47175583  9.22819275]
#  [ 2.27236081  5.58442225]
#  [10.05929716  6.65652333]
#  [-4.4940862   2.79472887]]
